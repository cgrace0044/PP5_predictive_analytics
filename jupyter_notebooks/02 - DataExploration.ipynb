# %% [markdown]
# # **Data Exploration Notebook**

# %% [markdown]
# ## Objectives
#
# * Answer business requirement:
#
# - Investigate the variables most strongly related to house sale price.
# - Understand patterns in the dataset that influence property value.
# - Generate analysis and code that can support the Streamlit app.
#
# ## Inputs
#
# *  `outputs/datasets/collection/house_prices_records.csv`
#
# ## Outputs
#
# * Code and visual insights that support business requirement 1.
#
#
# ## Additional Comments
#
# * This notebook belongs to the **Data Understanding** phase of CRISP-DM.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/PP5_predictive_analytics/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/PP5_predictive_analytics'

# %% [markdown]
# ---
